# %%
# %env ANYWIDGET_HMR=1

# %%
from glotaran.io import load_model,load_parameters

params = load_parameters("target_rcg_gcrcg_rcgcr_refine-params.yml")
model = load_model("target_rcg_gcrcg_rcgcr_refine.yml")

# %%
from pyglotaran_extras.widgets.kineticschemevisualizer import VisualizationOptions

vis_ops = VisualizationOptions(
    colour_node_mapping={
        "red": ["rcg_r1"],
        "blue": ["gcrcg_r1"],
        "green": ["rcgcr_r1"]
    },
)

# %%
from pyglotaran_extras.widgets.kineticschemevisualizer import visualize_megacomplex

visualize_megacomplex([
        "complex_rcg_dcm",
        "complex_gcrcg_dcm",
        "complex_rcgcr_dcm",
    ],
    model,
    params,
    vis_ops
)
